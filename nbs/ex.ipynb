# %% [markdown]
# # Template
#
# The `nbs` folder will contain example Jupyter Notebooks that highlight the functionality of the package.

# %%
1 + 1
# Out:
# 2

# %%
from template.base import add

add(7, 7)
# Out:
# 14
